# %% [markdown]
# ### Data Processing by adding OPD and IPD to dataset to see inequality

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### OPD 2556

# %%
df_opd_2556 = pd.read_excel('../add_data/dataset/OPD/OPD2556.xlsx')
df_opd_2556
# Out:
#    จำนวนผู้ป่วยนอก และอัตราต่อประชากร 1,000 คน  รายจังหวัด พ.ศ.2556  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 NaN
# 4                                                  01
# 5                                                  02
# 6                                                  03
# 7                                                  04
# 8                                                  05
# 9                                                  06
# 10                                                 07
# 11                                                 08
# 12                                                 09
# 13                                                 10
# 14                                                 11
# 15                                                 12
# ...

# %%
df_opd_2556 = df_opd_2556.loc[0:3]
df_opd_2556
# Out:
#   จำนวนผู้ป่วยนอก และอัตราต่อประชากร 1,000 คน  รายจังหวัด พ.ศ.2556  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1 Unnamed: 2   Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0            NaN        NaN          NaN        NaN          NaN        NaN
# 1  สาเหตุการป่วย     กระบี่          NaN  กาญจนบุรี          NaN  กาฬสินธุ์
# 2            NaN      จำนวน        อัตรา      จำนวน        อัตรา      จำนวน
# 3            รวม    1110208  2478.535661    1780883  2118.648544    3407362
#
#     Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 146 Unnamed: 147  \
# 0          NaN        NaN          NaN  ...          NaN          NaN
# 1          NaN  กำแพงเพชร          NaN  ...     อุดรธานี          NaN
# 2        อัตรา      จำนวน        อัตรา  ...        จำนวน        อัตรา
# ...

# %%
len(df_opd_2556.columns)
# Out:
# 156

# %%
# [f'Unnamed: {i}' for i in range(len(df_opd_2556.columns))]

# %%
df_opd_2556 = df_opd_2556.drop(columns=[f'Unnamed: {i}' for i in range(3,len(df_opd_2556.columns),2)])
df_opd_2556
# Out:
#   จำนวนผู้ป่วยนอก และอัตราต่อประชากร 1,000 คน  รายจังหวัด พ.ศ.2556  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0            NaN        NaN        NaN        NaN        NaN         NaN
# 1  สาเหตุการป่วย     กระบี่  กาญจนบุรี  กาฬสินธุ์  กำแพงเพชร     ขอนแก่น
# 2            NaN      จำนวน      จำนวน      จำนวน      จำนวน       จำนวน
# 3            รวม    1110208    1780883    3407362    2511719     7250904
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ... Unnamed: 136 Unnamed: 138  \
# 0         NaN         NaN         NaN  ...          NaN          NaN
# 1    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...     สุรินทร์      หนองคาย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# ...

# %%
df_opd_2556 = df_opd_2556.loc[1:3:2]
df_opd_2556
# Out:
#   จำนวนผู้ป่วยนอก และอัตราต่อประชากร 1,000 คน  รายจังหวัด พ.ศ.2556  \
# 1                                           กลุ่มโรค
# 3                                                NaN
#
#       Unnamed: 1 Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย     กระบี่  กาญจนบุรี  กาฬสินธุ์  กำแพงเพชร     ขอนแก่น
# 3            รวม    1110208    1780883    3407362    2511719     7250904
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ... Unnamed: 136 Unnamed: 138  \
# 1    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...     สุรินทร์      หนองคาย
# 3     1577151     1586269     3226006  ...      4130919      1749272
#
#   Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146 Unnamed: 148  \
# 1  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี    อุตรดิตถ์
# 3      1718309      1179579      1221845      3019377      1959943
#
#   Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุทัยธานี  อุบลราชธานี   ทั้งประเทศ
# 3      1652950      5387736    171909514
#
# [2 rows x 79 columns]

# %%
df_opd_2556.columns
# Out:
# Index(['จำนวนผู้ป่วยนอก และอัตราต่อประชากร 1,000 คน  รายจังหวัด พ.ศ.2556',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16',
#        'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
#        'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40',
#        'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48',
#        'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56',
#        'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64',
#        'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72',
#        'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80',
#        'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88',
#        'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96',
#        'Unnamed: 98', 'Unnamed: 100', 'Unnamed: 102', 'Unnamed: 104',
# ...

# %%
df_opd_2556 = df_opd_2556.drop(columns=df_opd_2556.columns[0])
df_opd_2556
# Out:
#       Unnamed: 1 Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย     กระบี่  กาญจนบุรี  กาฬสินธุ์  กำแพงเพชร     ขอนแก่น
# 3            รวม    1110208    1780883    3407362    2511719     7250904
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ... Unnamed: 136  \
# 1    จันทบุรี  ฉะเชิงเทรา      ชลบุรี      ชัยนาท  ...     สุรินทร์
# 3     1577151     1586269     3226006     1019815  ...      4130919
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1749272      1718309      1179579      1221845      3019377
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี   ทั้งประเทศ
# 3      1959943      1652950      5387736    171909514
#
# [2 rows x 78 columns]

# %%
prov_2556 = df_opd_2556.loc[1].values
prov_2556
# Out:
# array(['สาเหตุการป่วย', 'กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร',
#        'ขอนแก่น', 'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ',
#        'ชุมพร', 'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...

# %%
len(prov_2556)
# Out:
# 78

# %%
no_patient_2556 = df_opd_2556.loc[3].values
no_patient_2556
# Out:
# array(['รวม', 1110208, 1780883, 3407362, 2511719, 7250904, 1577151,
#        1586269, 3226006, 1019815, 3197242, 1232963, 3418302, 3967943,
#        1851220, 626376, 1566572, 1005127, 3406928, 2225590, 6015065,
#        4271094, 3658393, 2343540, 1559397, 1955562, 929015, 4891778,
#        1876089, 1376033, 1479512, 1351421, 3116985, 2139978, 429230,
#        1585056, 2095271, 3031249, 2071255, 2711954, 1886706, 831093,
#        2793921, 701992, 848174, 1866426, 632298, 3999158, 524737, 1517002,
#        3118635, 2297682, 2578493, 1675712, 2329825, 3950285, 3295893,
#        3446989, 693965, 2407691, 418850, 2119256, 1336503, 1070381,
#        880098, 2133750, 3317429, 2360183, 4130919, 1749272, 1718309,
#        1179579, 1221845, 3019377, 1959943, 1652950, 5387736, 171909514],
#       dtype=object)

# %%
new_df = pd.DataFrame(data={'Province':prov_2556,
                            'total_OPD': no_patient_2556})
new_df
# Out:
#          Province  total_OPD
# 0   สาเหตุการป่วย        รวม
# 1          กระบี่    1110208
# 2       กาญจนบุรี    1780883
# 3       กาฬสินธุ์    3407362
# 4       กำแพงเพชร    2511719
# ..            ...        ...
# 73       อุดรธานี    3019377
# 74      อุตรดิตถ์    1959943
# 75      อุทัยธานี    1652950
# 76    อุบลราชธานี    5387736
# 77     ทั้งประเทศ  171909514
#
# [78 rows x 2 columns]

# %%
new_df['Year'] = 2556
new_df
# Out:
#          Province  total_OPD  Year
# 0   สาเหตุการป่วย        รวม  2556
# 1          กระบี่    1110208  2556
# 2       กาญจนบุรี    1780883  2556
# 3       กาฬสินธุ์    3407362  2556
# 4       กำแพงเพชร    2511719  2556
# ..            ...        ...   ...
# 73       อุดรธานี    3019377  2556
# 74      อุตรดิตถ์    1959943  2556
# 75      อุทัยธานี    1652950  2556
# 76    อุบลราชธานี    5387736  2556
# 77     ทั้งประเทศ  171909514  2556
#
# [78 rows x 3 columns]

# %%
# อย่าลืมลบ 'ทั้งประเทศ'
new_df = new_df[:len(new_df)-1]
new_df = new_df[1:]
new_df
# Out:
#        Province total_OPD  Year
# 1        กระบี่   1110208  2556
# 2     กาญจนบุรี   1780883  2556
# 3     กาฬสินธุ์   3407362  2556
# 4     กำแพงเพชร   2511719  2556
# 5       ขอนแก่น   7250904  2556
# ..          ...       ...   ...
# 72   อำนาจเจริญ   1221845  2556
# 73     อุดรธานี   3019377  2556
# 74    อุตรดิตถ์   1959943  2556
# 75    อุทัยธานี   1652950  2556
# 76  อุบลราชธานี   5387736  2556
#
# [76 rows x 3 columns]

# %% [markdown]
# ### OPD 2557

# %%
df_opd_2557 = pd.read_excel('../add_data/dataset/OPD/OPD2557.xls')
df_opd_2557
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2557 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   5
# 9                                                   6
# 10                                                  7
# 11                                                  8
# 12                                                  9
# 13                                                 10
# 14                                                 11
# ...

# %%
df_opd_2557 = df_opd_2557.loc[0:3]
df_opd_2557
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2557 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2   Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0            NaN         NaN          NaN        NaN          NaN        NaN
# 1  สาเหตุการป่วย  ทั้งประเทศ          NaN     กระบี่          NaN  กาญจนบุรี
# 2            NaN       จำนวน        อัตรา      จำนวน        อัตรา      จำนวน
# 3            รวม   168125897  2836.799672     957304  2109.296023    2382065
#
#     Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 146 Unnamed: 147  \
# 0          NaN        NaN          NaN  ...          NaN          NaN
# 1          NaN  กาฬสินธุ์          NaN  ...   อำนาจเจริญ          NaN
# ...

# %%
len(df_opd_2557.columns)
# Out:
# 156

# %%
df_opd_2557 = df_opd_2557.drop(columns=[f'Unnamed: {i}' for i in range(3,len(df_opd_2557.columns),2)])
df_opd_2557
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2557 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0            NaN         NaN        NaN        NaN        NaN         NaN
# 1  สาเหตุการป่วย  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 2            NaN       จำนวน      จำนวน      จำนวน      จำนวน       จำนวน
# 3            รวม   168125897     957304    2382065    3109735     2585490
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 0         NaN         NaN         NaN  ...           NaN          NaN
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# ...

# %%
df_opd_2557 = df_opd_2557.loc[1:3:2]
df_opd_2557
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2557 (อัตราต่อประชากร 1,000 คน)  \
# 1                                           กลุ่มโรค
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   168125897     957304    2382065    3109735     2585490
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# 3     5270060     1716292     1765830  ...       3130546      3756480
#
#   Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146 Unnamed: 148  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1806662      1706402       644061      1155587      4580373
#
#   Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# ...

# %%
df_opd_2557.columns
# Out:
# Index(['จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2557 (อัตราต่อประชากร 1,000 คน)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16',
#        'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
#        'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40',
#        'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48',
#        'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56',
#        'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64',
#        'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72',
#        'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80',
#        'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88',
#        'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96',
# ...

# %%
df_opd_2557 = df_opd_2557.drop(columns=df_opd_2557.columns[0])
df_opd_2557
# Out:
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   168125897     957304    2382065    3109735     2585490
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ...  Unnamed: 136  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...  สุราษฎร์ธานี
# 3     5270060     1716292     1765830     3043960  ...       3130546
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      3756480      1806662      1706402       644061      1155587
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4580373      1795748      1574061      4883992
#
# [2 rows x 78 columns]

# %%
df_opd_2557 = df_opd_2557.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
df_opd_2557
# Out:
#   Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3     957304    2382065    3109735     2585490     5270060     1716292
#
#   Unnamed: 16 Unnamed: 18 Unnamed: 20 Unnamed: 22  ...  Unnamed: 136  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...  สุราษฎร์ธานี
# 3     1765830     3043960      839797     3408186  ...       3130546
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      3756480      1806662      1706402       644061      1155587
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4580373      1795748      1574061      4883992
#
# [2 rows x 76 columns]

# %%
prov_2557 = df_opd_2557.loc[1].values
prov_2557
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...

# %%
len(prov_2557)
# Out:
# 76

# %%
no_patient_2557 = df_opd_2557.loc[3].values
no_patient_2557
# Out:
# array([957304, 2382065, 3109735, 2585490, 5270060, 1716292, 1765830,
#        3043960, 839797, 3408186, 1378087, 3839033, 3858099, 1717201,
#        792210, 1850337, 916381, 3143382, 1937332, 7897513, 4095538,
#        3525817, 2422296, 1299975, 1911357, 1166177, 4643981, 1364084,
#        1747043, 1461019, 1644050, 2825524, 1775718, 297342, 1266377,
#        2152084, 3064781, 1940664, 2571655, 1797865, 687450, 2633369,
#        456364, 850849, 1901453, 624013, 4043052, 506481, 1025401, 2873837,
#        2048107, 2094371, 1592726, 2330699, 4385546, 3565044, 4063606,
#        526762, 1562426, 519528, 1390779, 1074138, 478017, 940958, 2087130,
#        3448238, 3130546, 3756480, 1806662, 1706402, 644061, 1155587,
#        4580373, 1795748, 1574061, 4883992], dtype=object)

# %%
df_2557 = pd.DataFrame(data={'Province':prov_2557,
                            'total_OPD': no_patient_2557})
df_2557
# Out:
#        Province total_OPD
# 0        กระบี่    957304
# 1     กาญจนบุรี   2382065
# 2     กาฬสินธุ์   3109735
# 3     กำแพงเพชร   2585490
# 4       ขอนแก่น   5270060
# ..          ...       ...
# 71   อำนาจเจริญ   1155587
# 72     อุดรธานี   4580373
# 73    อุตรดิตถ์   1795748
# 74    อุทัยธานี   1574061
# 75  อุบลราชธานี   4883992
#
# [76 rows x 2 columns]

# %%
df_2557['Year'] = 2557
df_2557
# Out:
#        Province total_OPD  Year
# 0        กระบี่    957304  2557
# 1     กาญจนบุรี   2382065  2557
# 2     กาฬสินธุ์   3109735  2557
# 3     กำแพงเพชร   2585490  2557
# 4       ขอนแก่น   5270060  2557
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1155587  2557
# 72     อุดรธานี   4580373  2557
# 73    อุตรดิตถ์   1795748  2557
# 74    อุทัยธานี   1574061  2557
# 75  อุบลราชธานี   4883992  2557
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2557], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 147   อำนาจเจริญ   1155587  2557
# 148     อุดรธานี   4580373  2557
# 149    อุตรดิตถ์   1795748  2557
# 150    อุทัยธานี   1574061  2557
# 151  อุบลราชธานี   4883992  2557
#
# [152 rows x 3 columns]

# %%
new_df.loc[new_df['Province']=='พระนครศรีอยุธยา']
# Out:
#             Province total_OPD  Year
# 31   พระนครศรีอยุธยา   3116985  2556
# 107  พระนครศรีอยุธยา   2825524  2557

# %% [markdown]
# ### OPD2558
# - Data is Missing...

# %% [markdown]
# ### OPD2559

# %%
df_opd_2559 = pd.read_excel('../add_data/dataset/OPD/OPD2559.xls')
df_opd_2559
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2559 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   5
# 9                                                   6
# 10                                                  7
# 11                                                  8
# 12                                                  9
# 13                                                 10
# 14                                                 11
# ...

# %%
df_opd_2559 = df_opd_2559.loc[0:3]
df_opd_2559
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2559 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2   Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0            NaN         NaN          NaN        NaN          NaN        NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ          NaN     กระบี่          NaN  กาญจนบุรี
# 2            NaN       จำนวน        อัตรา      จำนวน        อัตรา      จำนวน
# 3            รวม   221786620  3732.862594    1388593  3002.155527    3286276
#
#     Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 146 Unnamed: 147  \
# 0          NaN        NaN          NaN  ...          NaN          NaN
# 1          NaN  กาฬสินธุ์          NaN  ...   อำนาจเจริญ          NaN
# ...

# %%
len(df_opd_2559.columns)
# Out:
# 156

# %%
df_opd_2559 = df_opd_2559.drop(columns=[f'Unnamed: {i}' for i in range(3,len(df_opd_2559.columns),2)])
df_opd_2559
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2559 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0            NaN         NaN        NaN        NaN        NaN         NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 2            NaN       จำนวน      จำนวน      จำนวน      จำนวน       จำนวน
# 3            รวม   221786620    1388593    3286276    3662938     2868089
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 0         NaN         NaN         NaN  ...           NaN          NaN
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# ...

# %%
df_opd_2559 = df_opd_2559.loc[1:3:2]
df_opd_2559
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2559 (อัตราต่อประชากร 1,000 คน)  \
# 1                                           กลุ่มโรค
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   221786620    1388593    3286276    3662938     2868089
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# 3     6707144     1866094     2315007  ...       4067177      4034125
#
#   Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146 Unnamed: 148  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      2013150      1706513      1483757      1414471      5560716
#
#   Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# ...

# %%
df_opd_2559.columns
# Out:
# Index(['จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2559 (อัตราต่อประชากร 1,000 คน)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16',
#        'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
#        'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40',
#        'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48',
#        'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56',
#        'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64',
#        'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72',
#        'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80',
#        'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88',
#        'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96',
# ...

# %%
df_opd_2559 = df_opd_2559.drop(columns=df_opd_2559.columns[0])
df_opd_2559
# Out:
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   221786620    1388593    3286276    3662938     2868089
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ...  Unnamed: 136  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...  สุราษฎร์ธานี
# 3     6707144     1866094     2315007     5231241  ...       4067177
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4034125      2013150      1706513      1483757      1414471
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5560716      2108208      1868279      6771582
#
# [2 rows x 78 columns]

# %%
df_opd_2559 = df_opd_2559.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
df_opd_2559
# Out:
#   Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1388593    3286276    3662938     2868089     6707144     1866094
#
#   Unnamed: 16 Unnamed: 18 Unnamed: 20 Unnamed: 22  ...  Unnamed: 136  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...  สุราษฎร์ธานี
# 3     2315007     5231241     1825641     3733495  ...       4067177
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4034125      2013150      1706513      1483757      1414471
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5560716      2108208      1868279      6771582
#
# [2 rows x 76 columns]

# %%
prov_2559 = df_opd_2559.loc[1].values
prov_2559
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...

# %%
len(prov_2559)
# Out:
# 76

# %%
no_patient_2559 = df_opd_2559.loc[3].values
no_patient_2559
# Out:
# array([1388593, 3286276, 3662938, 2868089, 6707144, 1866094, 2315007,
#        5231241, 1825641, 3733495, 1678592, 5246422, 7639537, 2322405,
#        901935, 2165398, 1180026, 4096379, 2397278, 9583138, 5587451,
#        4579642, 3548300, 2111062, 2182606, 1382231, 5634866, 2392198,
#        2087310, 2091120, 2571753, 3265561, 2244327, 956303, 2158910,
#        2467386, 3778972, 2251035, 3233202, 2128830, 1138548, 3047458,
#        1175352, 1009582, 1949664, 1544464, 5020128, 628785, 2301612,
#        3079399, 1911667, 3180271, 1947868, 2608961, 5018186, 4371105,
#        4765007, 982346, 2854353, 990338, 2666789, 1667242, 2735240,
#        1080538, 2409872, 3925174, 4067177, 4034125, 2013150, 1706513,
#        1483757, 1414471, 5560716, 2108208, 1868279, 6771582], dtype=object)

# %%
df_2559 = pd.DataFrame(data={'Province':prov_2559,
                            'total_OPD': no_patient_2559})
df_2559
# Out:
#        Province total_OPD
# 0        กระบี่   1388593
# 1     กาญจนบุรี   3286276
# 2     กาฬสินธุ์   3662938
# 3     กำแพงเพชร   2868089
# 4       ขอนแก่น   6707144
# ..          ...       ...
# 71   อำนาจเจริญ   1414471
# 72     อุดรธานี   5560716
# 73    อุตรดิตถ์   2108208
# 74    อุทัยธานี   1868279
# 75  อุบลราชธานี   6771582
#
# [76 rows x 2 columns]

# %%
df_2559['Year'] = 2559
df_2559
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1388593  2559
# 1     กาญจนบุรี   3286276  2559
# 2     กาฬสินธุ์   3662938  2559
# 3     กำแพงเพชร   2868089  2559
# 4       ขอนแก่น   6707144  2559
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1414471  2559
# 72     อุดรธานี   5560716  2559
# 73    อุตรดิตถ์   2108208  2559
# 74    อุทัยธานี   1868279  2559
# 75  อุบลราชธานี   6771582  2559
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2559], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 223   อำนาจเจริญ   1414471  2559
# 224     อุดรธานี   5560716  2559
# 225    อุตรดิตถ์   2108208  2559
# 226    อุทัยธานี   1868279  2559
# 227  อุบลราชธานี   6771582  2559
#
# [228 rows x 3 columns]

# %% [markdown]
# ### OPD2560

# %%
df_opd_2560 = pd.read_excel('../add_data/dataset/OPD/OPD2560.xlsx')
df_opd_2560
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 NaN
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   5
# 9                                                   6
# 10                                                  7
# 11                                                  8
# 12                                                  9
# 13                                                 10
# 14                                                 11
# ...

# %%
df_opd_2560 = df_opd_2560.loc[0:3]
df_opd_2560
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2   Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0            NaN         NaN          NaN        NaN          NaN        NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ          NaN     กระบี่          NaN  กาญจนบุรี
# 2            NaN       จำนวน        อัตรา      จำนวน        อัตรา      จำนวน
# 3            รวม   220063238  3691.191877    1289648  2766.505422    3280597
#
#     Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 146 Unnamed: 147  \
# 0          NaN        NaN          NaN  ...          NaN          NaN
# 1          NaN  กาฬสินธุ์          NaN  ...   อำนาจเจริญ          NaN
# ...

# %%
len(df_opd_2560.columns)
# Out:
# 156

# %%
df_opd_2560 = df_opd_2560.drop(columns=[f'Unnamed: {i}' for i in range(3,len(df_opd_2560.columns),2)])
df_opd_2560
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0            NaN         NaN        NaN        NaN        NaN         NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 2            NaN       จำนวน      จำนวน      จำนวน      จำนวน       จำนวน
# 3            รวม   220063238    1289648    3280597    3583003     2857414
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 0         NaN         NaN         NaN  ...           NaN          NaN
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# ...

# %%
df_opd_2560 = df_opd_2560.loc[1:3:2]
df_opd_2560
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 1                                           กลุ่มโรค
# 3                                                NaN
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   220063238    1289648    3280597    3583003     2857414
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# 3     6993546     1901261     2370599  ...       4253070      4476725
#
#   Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146 Unnamed: 148  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1949392      1625094      1517288      1487820      5501699
#
#   Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# ...

# %%
df_opd_2560.columns
# Out:
# Index(['จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16',
#        'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
#        'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40',
#        'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48',
#        'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56',
#        'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64',
#        'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72',
#        'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80',
#        'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88',
#        'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96',
# ...

# %%
df_opd_2560 = df_opd_2560.drop(columns=df_opd_2560.columns[0])
df_opd_2560
# Out:
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            รวม   220063238    1289648    3280597    3583003     2857414
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ...  Unnamed: 136  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...  สุราษฎร์ธานี
# 3     6993546     1901261     2370599     4954613  ...       4253070
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4476725      1949392      1625094      1517288      1487820
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5501699      2122035      1823765      6691617
#
# [2 rows x 78 columns]

# %%
df_opd_2560 = df_opd_2560.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
df_opd_2560
# Out:
#   Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1289648    3280597    3583003     2857414     6993546     1901261
#
#   Unnamed: 16 Unnamed: 18 Unnamed: 20 Unnamed: 22  ...  Unnamed: 136  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...  สุราษฎร์ธานี
# 3     2370599     4954613     1833267     3668092  ...       4253070
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4476725      1949392      1625094      1517288      1487820
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5501699      2122035      1823765      6691617
#
# [2 rows x 76 columns]

# %%
prov_2560 = df_opd_2560.loc[1].values
prov_2560
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...

# %%
len(prov_2560)
# Out:
# 76

# %%
no_patient_2560 = df_opd_2560.loc[3].values
no_patient_2560
# Out:
# array([1289648, 3280597, 3583003, 2857414, 6993546, 1901261, 2370599,
#        4954613, 1833267, 3668092, 1703310, 5130937, 7641399, 2371775,
#        904008, 2182435, 1098107, 3799615, 2131340, 9848592, 5415132,
#        4563848, 3515044, 991874, 2232323, 1287377, 5397627, 2464414,
#        2063523, 1919380, 2112067, 3114141, 2180685, 969584, 2204748,
#        2425813, 3816485, 2360836, 3137470, 2090809, 1204564, 2911199,
#        1113350, 955600, 1902717, 1667682, 5115873, 617303, 2295099,
#        3457151, 2825181, 3457011, 1967010, 2513405, 5046481, 4226267,
#        4890485, 1002261, 2882801, 1015314, 2417479, 1772991, 2588588,
#        1095736, 2102276, 3764171, 4253070, 4476725, 1949392, 1625094,
#        1517288, 1487820, 5501699, 2122035, 1823765, 6691617], dtype=object)

# %%
df_2560 = pd.DataFrame(data={'Province':prov_2560,
                            'total_OPD': no_patient_2560})
df_2560
# Out:
#        Province total_OPD
# 0        กระบี่   1289648
# 1     กาญจนบุรี   3280597
# 2     กาฬสินธุ์   3583003
# 3     กำแพงเพชร   2857414
# 4       ขอนแก่น   6993546
# ..          ...       ...
# 71   อำนาจเจริญ   1487820
# 72     อุดรธานี   5501699
# 73    อุตรดิตถ์   2122035
# 74    อุทัยธานี   1823765
# 75  อุบลราชธานี   6691617
#
# [76 rows x 2 columns]

# %%
df_2560['Year'] = 2560
df_2560
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1289648  2560
# 1     กาญจนบุรี   3280597  2560
# 2     กาฬสินธุ์   3583003  2560
# 3     กำแพงเพชร   2857414  2560
# 4       ขอนแก่น   6993546  2560
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1487820  2560
# 72     อุดรธานี   5501699  2560
# 73    อุตรดิตถ์   2122035  2560
# 74    อุทัยธานี   1823765  2560
# 75  อุบลราชธานี   6691617  2560
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2560], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 299   อำนาจเจริญ   1487820  2560
# 300     อุดรธานี   5501699  2560
# 301    อุตรดิตถ์   2122035  2560
# 302    อุทัยธานี   1823765  2560
# 303  อุบลราชธานี   6691617  2560
#
# [304 rows x 3 columns]

# %% [markdown]
# ### OPD2561

# %%
df_opd_2561 = pd.read_excel('../add_data/dataset/OPD/OPD2561.xlsx')
df_opd_2561
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   5
# 9                                                   6
# 10                                                  7
# 11                                                  8
# 12                                                  9
# 13                                                 10
# 14                                                 11
# ...

# %%
df_opd_2561 = df_opd_2561.loc[0:3]
df_opd_2561
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1  Unnamed: 2  Unnamed: 3 Unnamed: 4   Unnamed: 5 Unnamed: 6  \
# 0            NaN         NaN         NaN        NaN          NaN        NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ         NaN     กระบี่          NaN  กาญจนบุรี
# 2            NaN       จำนวน       อัตรา      จำนวน        อัตรา      จำนวน
# 3            NaN   202989132  3392.69608    1246366  2652.706094    3214004
#
#     Unnamed: 7 Unnamed: 8   Unnamed: 9  ... Unnamed: 146 Unnamed: 147  \
# 0          NaN        NaN          NaN  ...          NaN          NaN
# 1          NaN  กาฬสินธุ์          NaN  ...   อำนาจเจริญ          NaN
# ...

# %%
len(df_opd_2561.columns)
# Out:
# 156

# %%
df_opd_2561 = df_opd_2561.drop(columns=[f'Unnamed: {i}' for i in range(3,len(df_opd_2561.columns),2)])
df_opd_2561
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 0                                                NaN
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 0            NaN         NaN        NaN        NaN        NaN         NaN
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 2            NaN       จำนวน      จำนวน      จำนวน      จำนวน       จำนวน
# 3            NaN   202989132    1246366    3214004    3356022     2812817
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 0         NaN         NaN         NaN  ...           NaN          NaN
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# ...

# %%
df_opd_2561 = df_opd_2561.loc[1:3:2]
df_opd_2561
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            NaN   202989132    1246366    3214004    3356022     2812817
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16  ...  Unnamed: 136 Unnamed: 138  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...  สุราษฎร์ธานี     สุรินทร์
# 3     5544608     1991994     2734985  ...       4052119      4179998
#
#   Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146 Unnamed: 148  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1793987      1536207      1386608      1368374      5049921
#
#   Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# ...

# %%
df_opd_2561.columns
# Out:
# Index(['จำนวนและอัตราผู้ป่วยนอกทั้งประเทศและรายจังหวัด (ไม่รวมกรุงเทพมหานคร) พ.ศ.2560 (อัตราต่อประชากร 1,000 คน)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8',
#        'Unnamed: 10', 'Unnamed: 12', 'Unnamed: 14', 'Unnamed: 16',
#        'Unnamed: 18', 'Unnamed: 20', 'Unnamed: 22', 'Unnamed: 24',
#        'Unnamed: 26', 'Unnamed: 28', 'Unnamed: 30', 'Unnamed: 32',
#        'Unnamed: 34', 'Unnamed: 36', 'Unnamed: 38', 'Unnamed: 40',
#        'Unnamed: 42', 'Unnamed: 44', 'Unnamed: 46', 'Unnamed: 48',
#        'Unnamed: 50', 'Unnamed: 52', 'Unnamed: 54', 'Unnamed: 56',
#        'Unnamed: 58', 'Unnamed: 60', 'Unnamed: 62', 'Unnamed: 64',
#        'Unnamed: 66', 'Unnamed: 68', 'Unnamed: 70', 'Unnamed: 72',
#        'Unnamed: 74', 'Unnamed: 76', 'Unnamed: 78', 'Unnamed: 80',
#        'Unnamed: 82', 'Unnamed: 84', 'Unnamed: 86', 'Unnamed: 88',
#        'Unnamed: 90', 'Unnamed: 92', 'Unnamed: 94', 'Unnamed: 96',
# ...

# %%
df_opd_2561 = df_opd_2561.drop(columns=df_opd_2561.columns[0])
df_opd_2561
# Out:
#       Unnamed: 1  Unnamed: 2 Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10  \
# 1  สาเหตุการป่วย  ทั่วประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร
# 3            NaN   202989132    1246366    3214004    3356022     2812817
#
#   Unnamed: 12 Unnamed: 14 Unnamed: 16 Unnamed: 18  ...  Unnamed: 136  \
# 1     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา      ชลบุรี  ...  สุราษฎร์ธานี
# 3     5544608     1991994     2734985     3467681  ...       4052119
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4179998      1793987      1536207      1386608      1368374
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5049921      1785663      1732595      6340921
#
# [2 rows x 78 columns]

# %%
df_opd_2561 = df_opd_2561.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
df_opd_2561
# Out:
#   Unnamed: 4 Unnamed: 6 Unnamed: 8 Unnamed: 10 Unnamed: 12 Unnamed: 14  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1246366    3214004    3356022     2812817     5544608     1991994
#
#   Unnamed: 16 Unnamed: 18 Unnamed: 20 Unnamed: 22  ...  Unnamed: 136  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...  สุราษฎร์ธานี
# 3     2734985     3467681     1881114     3492274  ...       4052119
#
#   Unnamed: 138 Unnamed: 140 Unnamed: 142 Unnamed: 144 Unnamed: 146  \
# 1     สุรินทร์      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      4179998      1793987      1536207      1386608      1368374
#
#   Unnamed: 148 Unnamed: 150 Unnamed: 152 Unnamed: 154
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5049921      1785663      1732595      6340921
#
# [2 rows x 76 columns]

# %%
prov_2561 = df_opd_2561.loc[1].values
prov_2561
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยโสธร', 'ยะลา', 'ร้อยเอ็ด', 'ระนอง', 'ระยอง',
#        'ราชบุรี', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ', 'สกลนคร',
#        'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม', 'สมุทรสาคร',
#        'สระแก้ว', 'สระบุรี', 'สิงห์บุรี', 'สุโขทัย', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'หนองคาย', 'หนองบัวลำภู', 'อ่างทอง',
# ...

# %%
len(prov_2561)
# Out:
# 76

# %%
no_patient_2561 = df_opd_2561.loc[3].values
no_patient_2561
# Out:
# array([1246366, 3214004, 3356022, 2812817, 5544608, 1991994, 2734985,
#        3467681, 1881114, 3492274, 1606286, 4764342, 5345625, 2099175,
#        914921, 2026608, 1141547, 3317899, 2100996, 6668454, 5312859,
#        4453075, 3709585, 1212213, 2076375, 1228069, 3480005, 2545276,
#        2020881, 2051015, 1971340, 3156029, 1975615, 986617, 2158648,
#        2306689, 3594982, 2126037, 2885865, 1917466, 1174502, 2749835,
#        1107418, 896772, 1669658, 1638631, 4733762, 588878, 2247067,
#        3267445, 2801858, 3169313, 1864469, 2417603, 4901578, 4019173,
#        4930703, 977873, 3001828, 864174, 2510808, 1767109, 2798259,
#        1106945, 2257591, 3403128, 4052119, 4179998, 1793987, 1536207,
#        1386608, 1368374, 5049921, 1785663, 1732595, 6340921], dtype=object)

# %%
df_2561 = pd.DataFrame(data={'Province':prov_2561,
                            'total_OPD': no_patient_2561})
df_2561
# Out:
#        Province total_OPD
# 0        กระบี่   1246366
# 1     กาญจนบุรี   3214004
# 2     กาฬสินธุ์   3356022
# 3     กำแพงเพชร   2812817
# 4       ขอนแก่น   5544608
# ..          ...       ...
# 71   อำนาจเจริญ   1368374
# 72     อุดรธานี   5049921
# 73    อุตรดิตถ์   1785663
# 74    อุทัยธานี   1732595
# 75  อุบลราชธานี   6340921
#
# [76 rows x 2 columns]

# %%
df_2561['Year'] = 2561
df_2561
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1246366  2561
# 1     กาญจนบุรี   3214004  2561
# 2     กาฬสินธุ์   3356022  2561
# 3     กำแพงเพชร   2812817  2561
# 4       ขอนแก่น   5544608  2561
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1368374  2561
# 72     อุดรธานี   5049921  2561
# 73    อุตรดิตถ์   1785663  2561
# 74    อุทัยธานี   1732595  2561
# 75  อุบลราชธานี   6340921  2561
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2561], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 375   อำนาจเจริญ   1368374  2561
# 376     อุดรธานี   5049921  2561
# 377    อุตรดิตถ์   1785663  2561
# 378    อุทัยธานี   1732595  2561
# 379  อุบลราชธานี   6340921  2561
#
# [380 rows x 3 columns]

# %% [markdown]
# ### OPD2562

# %%
df_opd_2562 = pd.read_excel('../add_data/dataset/OPD/OPD2562.xlsx')
df_opd_2562
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2562 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                            กลุ่มโรค
# 1                                                 NaN
# 2                                                 รวม
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 66                                                NaN
# 67                                                NaN
# 68                                                NaN
# 69  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 70  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0   สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# ...

# %%
df_opd_2562 = df_opd_2562.loc[0:2]
df_opd_2562
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2562 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                           กลุ่มโรค
# 1                                                NaN
# 2                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 1            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 2            NaN        รวม   241816724  4030.6874    1420358  3001.6843
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 0  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 1      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 2    3623940  4421.0349    3931891  ...      1499456    3969.5662
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2562.columns)
# Out:
# 157

# %%
df_opd_2562 = df_opd_2562.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2562.columns),2)])
df_opd_2562
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2562 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                           กลุ่มโรค
# 1                                                NaN
# 2                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 0  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 1            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 2            NaN        รวม   241816724    1420358    3623940    3931891
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 0   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 1       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 2     3083538     7741607     2161553  ...      4832961      2692290
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2562 = df_opd_2562.loc[0:2:2]
df_opd_2562
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2562 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                           กลุ่มโรค
# 2                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 0  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        รวม   241816724    1420358    3623940    3931891
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 0   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2     3083538     7741607     2161553  ...      4832961      2692290
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 0      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 2      2051034      1662325      1363349      1499456      5838858
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2562.columns
# Out:
# Index(['จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2562 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 5', 'Unnamed: 7',
#        'Unnamed: 9', 'Unnamed: 11', 'Unnamed: 13', 'Unnamed: 15',
#        'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 21', 'Unnamed: 23',
#        'Unnamed: 25', 'Unnamed: 27', 'Unnamed: 29', 'Unnamed: 31',
#        'Unnamed: 33', 'Unnamed: 35', 'Unnamed: 37', 'Unnamed: 39',
#        'Unnamed: 41', 'Unnamed: 43', 'Unnamed: 45', 'Unnamed: 47',
#        'Unnamed: 49', 'Unnamed: 51', 'Unnamed: 53', 'Unnamed: 55',
#        'Unnamed: 57', 'Unnamed: 59', 'Unnamed: 61', 'Unnamed: 63',
#        'Unnamed: 65', 'Unnamed: 67', 'Unnamed: 69', 'Unnamed: 71',
#        'Unnamed: 73', 'Unnamed: 75', 'Unnamed: 77', 'Unnamed: 79',
#        'Unnamed: 81', 'Unnamed: 83', 'Unnamed: 85', 'Unnamed: 87',
# ...

# %%
df_opd_2562 = df_opd_2562.drop(columns=df_opd_2562.columns[0])
df_opd_2562
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 0  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        รวม   241816724    1420358    3623940    3931891
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 0   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 2     3083538     7741607     2161553     2823022  ...      4832961
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 0      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 2      2692290      2051034      1662325      1363349      1499456
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 0     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 2      5838858      2227447      1947712      7606008
#
# [2 rows x 79 columns]

# %%
df_opd_2562 = df_opd_2562.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2562
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 0     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 2    1420358    3623940    3931891     3083538     7741607     2161553
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 0  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 2     2823022     6239622     1894490     4005910  ...      4832961
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 0      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 2      2692290      2051034      1662325      1363349      1499456
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 0     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 2      5838858      2227447      1947712      7606008
#
# [2 rows x 76 columns]

# %%
prov_2562 = df_opd_2562.loc[0].values
prov_2562
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2562)
# Out:
# 76

# %%
no_patient_2562 = df_opd_2562.loc[2].values
no_patient_2562
# Out:
# array([1420358, 3623940, 3931891, 3083538, 7741607, 2161553, 2823022,
#        6239622, 1894490, 4005910, 1847135, 5607295, 8531313, 2633606,
#        919104, 2175602, 1178849, 4040174, 2432712, 10019504, 6211519,
#        4886658, 4109252, 2667654, 2483404, 1455391, 5877663, 2896222,
#        2288590, 2010859, 2275700, 3196222, 2325526, 1093659, 2506208,
#        2647569, 4477494, 2422220, 3371789, 2213488, 1516484, 3360529,
#        1205362, 987991, 1875312, 2001972, 684856, 2487998, 3740103,
#        5298395, 2803997, 3609582, 2264643, 2756371, 5628325, 4517336,
#        5564108, 1121091, 3215594, 970020, 2412177, 2756326, 1905162,
#        1144198, 3956595, 4582445, 4832961, 2692290, 2051034, 1662325,
#        1363349, 1499456, 5838858, 2227447, 1947712, 7606008], dtype=object)

# %%
df_2562 = pd.DataFrame(data={'Province':prov_2562,
                            'total_OPD': no_patient_2562})
df_2562
# Out:
#        Province total_OPD
# 0        กระบี่   1420358
# 1     กาญจนบุรี   3623940
# 2     กาฬสินธุ์   3931891
# 3     กำแพงเพชร   3083538
# 4       ขอนแก่น   7741607
# ..          ...       ...
# 71   อำนาจเจริญ   1499456
# 72     อุดรธานี   5838858
# 73    อุตรดิตถ์   2227447
# 74    อุทัยธานี   1947712
# 75  อุบลราชธานี   7606008
#
# [76 rows x 2 columns]

# %%
df_2562['Year'] = 2562
df_2562
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1420358  2562
# 1     กาญจนบุรี   3623940  2562
# 2     กาฬสินธุ์   3931891  2562
# 3     กำแพงเพชร   3083538  2562
# 4       ขอนแก่น   7741607  2562
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1499456  2562
# 72     อุดรธานี   5838858  2562
# 73    อุตรดิตถ์   2227447  2562
# 74    อุทัยธานี   1947712  2562
# 75  อุบลราชธานี   7606008  2562
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2562], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 451   อำนาจเจริญ   1499456  2562
# 452     อุดรธานี   5838858  2562
# 453    อุตรดิตถ์   2227447  2562
# 454    อุทัยธานี   1947712  2562
# 455  อุบลราชธานี   7606008  2562
#
# [456 rows x 3 columns]

# %% [markdown]
# ### OPD2563

# %%
df_opd_2563 = pd.read_excel('../add_data/dataset/OPD/OPD2563.xlsx')
df_opd_2563
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2563 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 71  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN         NaN        NaN        NaN        NaN
# ...

# %%
df_opd_2563 = df_opd_2563.loc[1:3]
df_opd_2563
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2563 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 2            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 3            NaN        รวม   209613842  3499.4614    1206856  2540.0008
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 1  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 2      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 3    3241499  3962.7418    3350703  ...      1220505    3241.4635
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2563.columns)
# Out:
# 157

# %%
df_opd_2563 = df_opd_2563.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2563.columns),2)])
df_opd_2563
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2563 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 3            NaN        รวม   209613842    1206856    3241499    3350703
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 3     2731633     6848821     1953459  ...      4157960      2342188
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2563 = df_opd_2563.loc[1:3:2]
df_opd_2563
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2563 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   209613842    1206856    3241499    3350703
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 3     2731633     6848821     1953459  ...      4157960      2342188
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1848350      1478969      1159907      1220505      5065260
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2563 = df_opd_2563.drop(columns=df_opd_2563.columns[0])
df_opd_2563
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   209613842    1206856    3241499    3350703
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 3     2731633     6848821     1953459     2361590  ...      4157960
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2342188      1848350      1478969      1159907      1220505
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5065260      2016572      1688780      6474390
#
# [2 rows x 79 columns]

# %%
df_opd_2563 = df_opd_2563.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2563
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1206856    3241499    3350703     2731633     6848821     1953459
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 3     2361590     5220666     1656112     3425126  ...      4157960
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2342188      1848350      1478969      1159907      1220505
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5065260      2016572      1688780      6474390
#
# [2 rows x 76 columns]

# %%
prov_2563 = df_opd_2563.loc[1].values
prov_2563
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2563)
# Out:
# 76

# %%
no_patient_2563 = df_opd_2563.loc[3].values
no_patient_2563
# Out:
# array([1206856, 3241499, 3350703, 2731633, 6848821, 1953459, 2361590,
#        5220666, 1656112, 3425126, 1692205, 5048932, 7480924, 2238210,
#        808654, 1924110, 933714, 3373078, 2204331, 8810088, 5327941,
#        4469817, 3053295, 2069565, 2105664, 1254070, 4978837, 2548879,
#        2077707, 1921138, 1857266, 2685549, 2019832, 982787, 2171133,
#        2339765, 4018078, 2073941, 3005477, 1917096, 1212526, 2932171,
#        991269, 862241, 1591494, 1657972, 588476, 2155358, 3160232,
#        4621746, 2328387, 3246642, 1962575, 2527550, 5052606, 3778867,
#        4828275, 978012, 2668314, 930028, 2177880, 2428526, 1612613,
#        987579, 3529825, 3961249, 4157960, 2342188, 1848350, 1478969,
#        1159907, 1220505, 5065260, 2016572, 1688780, 6474390], dtype=object)

# %%
df_2563 = pd.DataFrame(data={'Province':prov_2563,
                            'total_OPD': no_patient_2563})
df_2563
# Out:
#        Province total_OPD
# 0        กระบี่   1206856
# 1     กาญจนบุรี   3241499
# 2     กาฬสินธุ์   3350703
# 3     กำแพงเพชร   2731633
# 4       ขอนแก่น   6848821
# ..          ...       ...
# 71   อำนาจเจริญ   1220505
# 72     อุดรธานี   5065260
# 73    อุตรดิตถ์   2016572
# 74    อุทัยธานี   1688780
# 75  อุบลราชธานี   6474390
#
# [76 rows x 2 columns]

# %%
df_2563['Year'] = 2563
df_2563
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1206856  2563
# 1     กาญจนบุรี   3241499  2563
# 2     กาฬสินธุ์   3350703  2563
# 3     กำแพงเพชร   2731633  2563
# 4       ขอนแก่น   6848821  2563
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1220505  2563
# 72     อุดรธานี   5065260  2563
# 73    อุตรดิตถ์   2016572  2563
# 74    อุทัยธานี   1688780  2563
# 75  อุบลราชธานี   6474390  2563
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2563], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 527   อำนาจเจริญ   1220505  2563
# 528     อุดรธานี   5065260  2563
# 529    อุตรดิตถ์   2016572  2563
# 530    อุทัยธานี   1688780  2563
# 531  อุบลราชธานี   6474390  2563
#
# [532 rows x 3 columns]

# %% [markdown]
# ### OPD2564

# %%
df_opd_2564 = pd.read_excel('../add_data/dataset/OPD/OPD2564.xlsx')
df_opd_2564
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2564 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 71  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN         NaN        NaN        NaN        NaN
# ...

# %%
df_opd_2564 = df_opd_2564.loc[1:3]
df_opd_2564
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2564 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 2            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 3            NaN        รวม   175370320  2934.8242     991758  2081.9244
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 1  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 2      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 3    2850861  3495.0514    2784371  ...      1047124    2788.6199
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2564.columns)
# Out:
# 157

# %%
df_opd_2564 = df_opd_2564.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2564.columns),2)])
df_opd_2564
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2564 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 3            NaN        รวม   175370320     991758    2850861    2784371
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 3     2247230     5409493     1517381  ...      3487198      2162404
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2564 = df_opd_2564.loc[1:3:2]
df_opd_2564
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2564 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   175370320     991758    2850861    2784371
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 3     2247230     5409493     1517381  ...      3487198      2162404
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1593525      1200202       899135      1047124      4471466
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2564 = df_opd_2564.drop(columns=df_opd_2564.columns[0])
df_opd_2564
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   175370320     991758    2850861    2784371
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 3     2247230     5409493     1517381     1733635  ...      3487198
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2162404      1593525      1200202       899135      1047124
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4471466      1767370      1539460      5432083
#
# [2 rows x 79 columns]

# %%
df_opd_2564 = df_opd_2564.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2564
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3     991758    2850861    2784371     2247230     5409493     1517381
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 3     1733635     4236575     1489887     2938043  ...      3487198
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2162404      1593525      1200202       899135      1047124
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4471466      1767370      1539460      5432083
#
# [2 rows x 76 columns]

# %%
prov_2564 = df_opd_2564.loc[1].values
prov_2564
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2564)
# Out:
# 76

# %%
no_patient_2564 = df_opd_2564.loc[3].values
no_patient_2564
# Out:
# array([991758, 2850861, 2784371, 2247230, 5409493, 1517381, 1733635,
#        4236575, 1489887, 2938043, 1370275, 4153990, 6403209, 1795359,
#        626452, 1364492, 780805, 2397761, 1867906, 7759510, 4543157,
#        3962201, 2901760, 1594532, 1755091, 1000008, 4140675, 2053703,
#        1861040, 1506857, 1360843, 2064063, 1886863, 832140, 1859029,
#        2052215, 3425590, 1717139, 2510285, 1673132, 1081162, 2363236,
#        867240, 804313, 1141190, 1456109, 521022, 1700573, 2599487,
#        3974671, 1891371, 3035681, 1579614, 2141477, 4415267, 3137626,
#        3789303, 817485, 2101318, 774175, 1808540, 1942049, 1324077,
#        823680, 2917675, 3342696, 3487198, 2162404, 1593525, 1200202,
#        899135, 1047124, 4471466, 1767370, 1539460, 5432083], dtype=object)

# %%
df_2564 = pd.DataFrame(data={'Province':prov_2564,
                            'total_OPD': no_patient_2564})
df_2564
# Out:
#        Province total_OPD
# 0        กระบี่    991758
# 1     กาญจนบุรี   2850861
# 2     กาฬสินธุ์   2784371
# 3     กำแพงเพชร   2247230
# 4       ขอนแก่น   5409493
# ..          ...       ...
# 71   อำนาจเจริญ   1047124
# 72     อุดรธานี   4471466
# 73    อุตรดิตถ์   1767370
# 74    อุทัยธานี   1539460
# 75  อุบลราชธานี   5432083
#
# [76 rows x 2 columns]

# %%
df_2564['Year'] = 2564
df_2564
# Out:
#        Province total_OPD  Year
# 0        กระบี่    991758  2564
# 1     กาญจนบุรี   2850861  2564
# 2     กาฬสินธุ์   2784371  2564
# 3     กำแพงเพชร   2247230  2564
# 4       ขอนแก่น   5409493  2564
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1047124  2564
# 72     อุดรธานี   4471466  2564
# 73    อุตรดิตถ์   1767370  2564
# 74    อุทัยธานี   1539460  2564
# 75  อุบลราชธานี   5432083  2564
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2564], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 603   อำนาจเจริญ   1047124  2564
# 604     อุดรธานี   4471466  2564
# 605    อุตรดิตถ์   1767370  2564
# 606    อุทัยธานี   1539460  2564
# 607  อุบลราชธานี   5432083  2564
#
# [608 rows x 3 columns]

# %% [markdown]
# ### OPD2565

# %%
df_opd_2565 = pd.read_excel('../add_data/dataset/OPD/OPD2565.xlsx')
df_opd_2565
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2565 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 71  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN         NaN        NaN        NaN        NaN
# ...

# %%
df_opd_2565 = df_opd_2565.loc[1:3]
df_opd_2565
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2565 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 2            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 3            NaN        รวม   202374470  3387.5517    1259039  2636.9739
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 1  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 2      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 3    3306974  4049.3989    3190485  ...      1068770    2849.3011
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2565.columns)
# Out:
# 157

# %%
df_opd_2565 = df_opd_2565.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2565.columns),2)])
df_opd_2565
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2565 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 3            NaN        รวม   202374470    1259039    3306974    3190485
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 3     2655865     6517425     1880130  ...      4084053      2458816
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2565 = df_opd_2565.loc[1:3:2]
df_opd_2565
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2565 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   202374470    1259039    3306974    3190485
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 3     2655865     6517425     1880130  ...      4084053      2458816
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1815275      1200114      1002582      1068770      4998123
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2565 = df_opd_2565.drop(columns=df_opd_2565.columns[0])
df_opd_2565
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   202374470    1259039    3306974    3190485
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 3     2655865     6517425     1880130     2230378  ...      4084053
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2458816      1815275      1200114      1002582      1068770
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4998123      1894572      1521726      5986758
#
# [2 rows x 79 columns]

# %%
df_opd_2565 = df_opd_2565.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2565
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1259039    3306974    3190485     2655865     6517425     1880130
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 3     2230378     5267553     1680237     3220833  ...      4084053
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2458816      1815275      1200114      1002582      1068770
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      4998123      1894572      1521726      5986758
#
# [2 rows x 76 columns]

# %%
prov_2565 = df_opd_2565.loc[1].values
prov_2565
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2565)
# Out:
# 76

# %%
no_patient_2565 = df_opd_2565.loc[3].values
no_patient_2565
# Out:
# array([1259039, 3306974, 3190485, 2655865, 6517425, 1880130, 2230378,
#        5267553, 1680237, 3220833, 1638117, 4793609, 7219893, 2163769,
#        710396, 1914784, 902557, 3082587, 1969062, 9066675, 5148165,
#        4393118, 3711174, 1922134, 2038408, 1154475, 4985773, 2460597,
#        2087796, 1854330, 1574988, 2457617, 2125239, 955926, 2065864,
#        2217066, 4020615, 1915262, 2916183, 1985401, 1290032, 2752767,
#        920005, 899200, 1382728, 1575831, 584171, 2060351, 2889117,
#        4385966, 2284197, 3110905, 1796244, 2354913, 4709680, 3568826,
#        4613065, 964784, 2625270, 841901, 2198899, 2393026, 1571095,
#        1004509, 3223081, 3682619, 4084053, 2458816, 1815275, 1200114,
#        1002582, 1068770, 4998123, 1894572, 1521726, 5986758], dtype=object)

# %%
df_2565 = pd.DataFrame(data={'Province':prov_2565,
                            'total_OPD': no_patient_2565})
df_2565
# Out:
#        Province total_OPD
# 0        กระบี่   1259039
# 1     กาญจนบุรี   3306974
# 2     กาฬสินธุ์   3190485
# 3     กำแพงเพชร   2655865
# 4       ขอนแก่น   6517425
# ..          ...       ...
# 71   อำนาจเจริญ   1068770
# 72     อุดรธานี   4998123
# 73    อุตรดิตถ์   1894572
# 74    อุทัยธานี   1521726
# 75  อุบลราชธานี   5986758
#
# [76 rows x 2 columns]

# %%
df_2565['Year'] = 2565
df_2565
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1259039  2565
# 1     กาญจนบุรี   3306974  2565
# 2     กาฬสินธุ์   3190485  2565
# 3     กำแพงเพชร   2655865  2565
# 4       ขอนแก่น   6517425  2565
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1068770  2565
# 72     อุดรธานี   4998123  2565
# 73    อุตรดิตถ์   1894572  2565
# 74    อุทัยธานี   1521726  2565
# 75  อุบลราชธานี   5986758  2565
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2565], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 679   อำนาจเจริญ   1068770  2565
# 680     อุดรธานี   4998123  2565
# 681    อุตรดิตถ์   1894572  2565
# 682    อุทัยธานี   1521726  2565
# 683  อุบลราชธานี   5986758  2565
#
# [684 rows x 3 columns]

# %% [markdown]
# ### OPD2566

# %%
df_opd_2566 = pd.read_excel('../add_data/dataset/OPD/OPD2566.xlsx')
df_opd_2566
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2566 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 71  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN         NaN        NaN        NaN        NaN
# ...

# %%
df_opd_2566 = df_opd_2566.loc[1:3]
df_opd_2566
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2566 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 2            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 3            NaN        รวม   220728256  3697.2537    1019057  2128.1696
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 1  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 2      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 3    3320907  4066.4997    3378688  ...      1281055     3425.409
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2566.columns)
# Out:
# 157

# %%
df_opd_2566 = df_opd_2566.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2566.columns),2)])
df_opd_2566
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2566 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 3            NaN        รวม   220728256    1019057    3320907    3378688
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 3     2838261     6731333     2051426  ...      4451494      2599901
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2566 = df_opd_2566.loc[1:3:2]
df_opd_2566
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2566 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   220728256    1019057    3320907    3378688
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 3     2838261     6731333     2051426  ...      4451494      2599901
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1849164      1271819      1116083      1281055      5266125
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2566 = df_opd_2566.drop(columns=df_opd_2566.columns[0])
df_opd_2566
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   220728256    1019057    3320907    3378688
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 3     2838261     6731333     2051426     2449325  ...      4451494
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2599901      1849164      1271819      1116083      1281055
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5266125      2132892      1721238      6779226
#
# [2 rows x 79 columns]

# %%
df_opd_2566 = df_opd_2566.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2566
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3    1019057    3320907    3378688     2838261     6731333     2051426
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 3     2449325     5779741     1770897     3562002  ...      4451494
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2599901      1849164      1271819      1116083      1281055
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5266125      2132892      1721238      6779226
#
# [2 rows x 76 columns]

# %%
prov_2566 = df_opd_2566.loc[1].values
prov_2566
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2566)
# Out:
# 76

# %%
no_patient_2566 = df_opd_2566.loc[3].values
no_patient_2566
# Out:
# array([1019057, 3320907, 3378688, 2838261, 6731333, 2051426, 2449325,
#        5779741, 1770897, 3562002, 1764431, 5275997, 8083821, 2403762,
#        824481, 2126667, 1009937, 3103210, 2116124, 9853708, 5836033,
#        4682116, 4368265, 2173550, 2304699, 1281770, 5347849, 2723385,
#        2104644, 1908033, 1819910, 2737957, 2274496, 1052309, 2302109,
#        2303040, 4183392, 2013542, 3085116, 2052367, 1395016, 2946698,
#        1066169, 971594, 1587059, 1807695, 653021, 2308463, 3666505,
#        4379353, 2578292, 3481750, 1965102, 2565568, 4967916, 4043799,
#        5207146, 1075015, 3009486, 899926, 2670129, 2713106, 1674336,
#        1097911, 3434194, 4075653, 4451494, 2599901, 1849164, 1271819,
#        1116083, 1281055, 5266125, 2132892, 1721238, 6779226], dtype=object)

# %%
df_2566 = pd.DataFrame(data={'Province':prov_2566,
                            'total_OPD': no_patient_2566})
df_2566
# Out:
#        Province total_OPD
# 0        กระบี่   1019057
# 1     กาญจนบุรี   3320907
# 2     กาฬสินธุ์   3378688
# 3     กำแพงเพชร   2838261
# 4       ขอนแก่น   6731333
# ..          ...       ...
# 71   อำนาจเจริญ   1281055
# 72     อุดรธานี   5266125
# 73    อุตรดิตถ์   2132892
# 74    อุทัยธานี   1721238
# 75  อุบลราชธานี   6779226
#
# [76 rows x 2 columns]

# %%
df_2566['Year'] = 2566
df_2566
# Out:
#        Province total_OPD  Year
# 0        กระบี่   1019057  2566
# 1     กาญจนบุรี   3320907  2566
# 2     กาฬสินธุ์   3378688  2566
# 3     กำแพงเพชร   2838261  2566
# 4       ขอนแก่น   6731333  2566
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1281055  2566
# 72     อุดรธานี   5266125  2566
# 73    อุตรดิตถ์   2132892  2566
# 74    อุทัยธานี   1721238  2566
# 75  อุบลราชธานี   6779226  2566
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2566], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 755   อำนาจเจริญ   1281055  2566
# 756     อุดรธานี   5266125  2566
# 757    อุตรดิตถ์   2132892  2566
# 758    อุทัยธานี   1721238  2566
# 759  อุบลราชธานี   6779226  2566
#
# [760 rows x 3 columns]

# %% [markdown]
# ### OPD2567

# %%
df_opd_2567 = pd.read_excel('../add_data/dataset/OPD/OPD2567.xlsx')
df_opd_2567
# Out:
#    จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2567 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 0                                                 NaN
# 1                                            กลุ่มโรค
# 2                                                 NaN
# 3                                                 รวม
# 4                                                 NaN
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70  รวบรวม/ วิเคราะห์: กองยุทธศาสตร์และแผนงาน สําน...
# 71  แหล่งข้อมูล:  ฐานข้อมูลตามโครงสร้างมาตรฐานข้อม...
#
#        Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0             NaN        NaN         NaN        NaN        NaN        NaN
# ...

# %%
df_opd_2567 = df_opd_2567.loc[1:3]
df_opd_2567
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2567 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ        NaN     กระบี่        NaN
# 2            NaN        NaN       จำนวน      อัตรา      จำนวน      อัตรา
# 3            NaN        รวม   203313886  3408.7201     927689  1929.5138
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 147 Unnamed: 148  \
# 1  กาญจนบุรี        NaN  กาฬสินธุ์  ...   อำนาจเจริญ          NaN
# 2      จำนวน      อัตรา      จำนวน  ...        จำนวน        อัตรา
# 3    3069600  3760.3131    3273680  ...      1343575    3608.1235
#
#   Unnamed: 149 Unnamed: 150 Unnamed: 151 Unnamed: 152 Unnamed: 153  \
# ...

# %%
len(df_opd_2567.columns)
# Out:
# 157

# %%
df_opd_2567 = df_opd_2567.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_opd_2567.columns),2)])
df_opd_2567
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2567 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 2                                                NaN
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 2            NaN        NaN       จำนวน      จำนวน      จำนวน      จำนวน
# 3            NaN        รวม   203313886     927689    3069600    3273680
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 2       จำนวน       จำนวน       จำนวน  ...        จำนวน        จำนวน
# 3     2755856     6123415     1870443  ...      4065032      2525196
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# ...

# %%
df_opd_2567 = df_opd_2567.loc[1:3:2]
df_opd_2567
# Out:
#   จำนวนและอัตราผู้ป่วยนอกทั้งประเทศต่อประชากร 1,000 คน จำแนกตามสาเหตุการป่วย เปรียบเทียบรายจังหวัด ปี พ.ศ. 2567 (ไม่รวม กรุงเทพมหานคร) (หน่วยนับ: รายโรค)  \
# 1                                           กลุ่มโรค
# 3                                                รวม
#
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   203313886     927689    3069600    3273680
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15  ... Unnamed: 137 Unnamed: 139  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ...     สุรินทร์      สุโขทัย
# 3     2755856     6123415     1870443  ...      4065032      2525196
#
#   Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147 Unnamed: 149  \
# 1      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ     อุดรธานี
# 3      1601849      1167934      1079977      1343575      5369440
#
#   Unnamed: 151 Unnamed: 153 Unnamed: 155
# ...

# %%
df_opd_2567 = df_opd_2567.drop(columns=df_opd_2567.columns[0])
df_opd_2567
# Out:
#       Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 5 Unnamed: 7 Unnamed: 9  \
# 1  สาเหตุการป่วย        เพศ  ทั้งประเทศ     กระบี่  กาญจนบุรี  กาฬสินธุ์
# 3            NaN        รวม   203313886     927689    3069600    3273680
#
#   Unnamed: 11 Unnamed: 13 Unnamed: 15 Unnamed: 17  ... Unnamed: 137  \
# 1   กำแพงเพชร     ขอนแก่น    จันทบุรี  ฉะเชิงเทรา  ...     สุรินทร์
# 3     2755856     6123415     1870443     2265259  ...      4065032
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2525196      1601849      1167934      1079977      1343575
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5369440      2104747      1627107      6279147
#
# [2 rows x 79 columns]

# %%
df_opd_2567 = df_opd_2567.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_opd_2567
# Out:
#   Unnamed: 5 Unnamed: 7 Unnamed: 9 Unnamed: 11 Unnamed: 13 Unnamed: 15  \
# 1     กระบี่  กาญจนบุรี  กาฬสินธุ์   กำแพงเพชร     ขอนแก่น    จันทบุรี
# 3     927689    3069600    3273680     2755856     6123415     1870443
#
#   Unnamed: 17 Unnamed: 19 Unnamed: 21 Unnamed: 23  ... Unnamed: 137  \
# 1  ฉะเชิงเทรา      ชลบุรี      ชัยนาท     ชัยภูมิ  ...     สุรินทร์
# 3     2265259     5064553     1630001     3148887  ...      4065032
#
#   Unnamed: 139 Unnamed: 141 Unnamed: 143 Unnamed: 145 Unnamed: 147  \
# 1      สุโขทัย      หนองคาย  หนองบัวลำภู      อ่างทอง   อำนาจเจริญ
# 3      2525196      1601849      1167934      1079977      1343575
#
#   Unnamed: 149 Unnamed: 151 Unnamed: 153 Unnamed: 155
# 1     อุดรธานี    อุตรดิตถ์    อุทัยธานี  อุบลราชธานี
# 3      5369440      2104747      1627107      6279147
#
# [2 rows x 76 columns]

# %%
prov_2567 = df_opd_2567.loc[1].values
prov_2567
# Out:
# array(['กระบี่', 'กาญจนบุรี', 'กาฬสินธุ์', 'กำแพงเพชร', 'ขอนแก่น',
#        'จันทบุรี', 'ฉะเชิงเทรา', 'ชลบุรี', 'ชัยนาท', 'ชัยภูมิ', 'ชุมพร',
#        'เชียงราย', 'เชียงใหม่', 'ตรัง', 'ตราด', 'ตาก', 'นครนายก',
#        'นครปฐม', 'นครพนม', 'นครราชสีมา', 'นครศรีธรรมราช', 'นครสวรรค์',
#        'นนทบุรี', 'นราธิวาส', 'น่าน', 'บึงกาฬ', 'บุรีรัมย์', 'ปทุมธานี',
#        'ประจวบคีรีขันธ์', 'ปราจีนบุรี', 'ปัตตานี', 'พระนครศรีอยุธยา',
#        'พะเยา', 'พังงา', 'พัทลุง', 'พิจิตร', 'พิษณุโลก', 'เพชรบุรี',
#        'เพชรบูรณ์', 'แพร่', 'ภูเก็ต', 'มหาสารคาม', 'มุกดาหาร',
#        'แม่ฮ่องสอน', 'ยะลา', 'ยโสธร', 'ระนอง', 'ระยอง', 'ราชบุรี',
#        'ร้อยเอ็ด', 'ลพบุรี', 'ลำปาง', 'ลำพูน', 'เลย', 'ศรีสะเกษ',
#        'สกลนคร', 'สงขลา', 'สตูล', 'สมุทรปราการ', 'สมุทรสงคราม',
#        'สมุทรสาคร', 'สระบุรี', 'สระแก้ว', 'สิงห์บุรี', 'สุพรรณบุรี',
#        'สุราษฎร์ธานี', 'สุรินทร์', 'สุโขทัย', 'หนองคาย', 'หนองบัวลำภู',
#        'อ่างทอง', 'อำนาจเจริญ', 'อุดรธานี', 'อุตรดิตถ์', 'อุทัยธานี',
# ...

# %%
len(prov_2567)
# Out:
# 76

# %%
no_patient_2567 = df_opd_2567.loc[3].values
no_patient_2567
# Out:
# array([927689, 3069600, 3273680, 2755856, 6123415, 1870443, 2265259,
#        5064553, 1630001, 3148887, 1700590, 4569157, 6964724, 2180325,
#        779293, 2036452, 938403, 2490316, 2154322, 8294500, 5510031,
#        4265926, 3776009, 2142723, 2004080, 1252087, 4959841, 2410309,
#        1798804, 1753321, 1643456, 2580110, 1987495, 961913, 2156298,
#        2106584, 3834232, 1745272, 3211189, 1873193, 1289900, 2690940,
#        1096580, 914187, 1518835, 1710987, 622510, 1962216, 3392130,
#        4125211, 2487489, 3259169, 1741869, 2530043, 4851032, 3951321,
#        4347898, 1002092, 2709959, 877154, 2542002, 2488045, 1671836,
#        1095255, 3214510, 3846374, 4065032, 2525196, 1601849, 1167934,
#        1079977, 1343575, 5369440, 2104747, 1627107, 6279147], dtype=object)

# %%
df_2567 = pd.DataFrame(data={'Province':prov_2567,
                            'total_OPD': no_patient_2567})
df_2567
# Out:
#        Province total_OPD
# 0        กระบี่    927689
# 1     กาญจนบุรี   3069600
# 2     กาฬสินธุ์   3273680
# 3     กำแพงเพชร   2755856
# 4       ขอนแก่น   6123415
# ..          ...       ...
# 71   อำนาจเจริญ   1343575
# 72     อุดรธานี   5369440
# 73    อุตรดิตถ์   2104747
# 74    อุทัยธานี   1627107
# 75  อุบลราชธานี   6279147
#
# [76 rows x 2 columns]

# %%
df_2567['Year'] = 2567
df_2567
# Out:
#        Province total_OPD  Year
# 0        กระบี่    927689  2567
# 1     กาญจนบุรี   3069600  2567
# 2     กาฬสินธุ์   3273680  2567
# 3     กำแพงเพชร   2755856  2567
# 4       ขอนแก่น   6123415  2567
# ..          ...       ...   ...
# 71   อำนาจเจริญ   1343575  2567
# 72     อุดรธานี   5369440  2567
# 73    อุตรดิตถ์   2104747  2567
# 74    อุทัยธานี   1627107  2567
# 75  อุบลราชธานี   6279147  2567
#
# [76 rows x 3 columns]

# %%
new_df = pd.concat([new_df, df_2567], ignore_index=True)
new_df
# Out:
#         Province total_OPD  Year
# 0         กระบี่   1110208  2556
# 1      กาญจนบุรี   1780883  2556
# 2      กาฬสินธุ์   3407362  2556
# 3      กำแพงเพชร   2511719  2556
# 4        ขอนแก่น   7250904  2556
# ..           ...       ...   ...
# 831   อำนาจเจริญ   1343575  2567
# 832     อุดรธานี   5369440  2567
# 833    อุตรดิตถ์   2104747  2567
# 834    อุทัยธานี   1627107  2567
# 835  อุบลราชธานี   6279147  2567
#
# [836 rows x 3 columns]

# %% [markdown]
# ### Test

# %%
test1 = pd.DataFrame(data={'col1':[1,2,3],
                           'col2':[4,5,6],
                           'Year':[2556,2556,2556]})
test1
# Out:
#    col1  col2  Year
# 0     1     4  2556
# 1     2     5  2556
# 2     3     6  2556

# %%
test2 = pd.DataFrame(data={'col1':[7,8,9],
                           'col2':[10,11,12],
                           'Year':[2557,2557,2557]})
test2
# Out:
#    col1  col2  Year
# 0     7    10  2557
# 1     8    11  2557
# 2     9    12  2557

# %%
pd.concat([test1, test2], ignore_index=True)
# Out:
#    col1  col2  Year
# 0     1     4  2556
# 1     2     5  2556
# 2     3     6  2556
# 3     7    10  2557
# 4     8    11  2557
# 5     9    12  2557

# %%
df_year_province = pd.read_csv('./df_year_province.csv').drop(columns=['Unnamed: 0'])
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm
# 0     2554         กระบี่    647          krabi   5319.415247
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768
# ...    ...            ...    ...            ...           ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079
# 1075  2567            เลย   1488           loei  10490.079232
# 1076  2567           แพร่   1185          phrae   6484.532497
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567
#
# [1078 rows x 5 columns]

# %%
df_year_province.loc[(df_year_province['ปี'] == 2554) & (df_year_province['จังหวัด'] == 'กระบี่')]
# Out:
#      ปี จังหวัด  จำนวน province_en    area_sqkm
# 0  2554  กระบี่    647       krabi  5319.415247

# %%
new_df.loc[(new_df['Year'] == 2557) & (new_df['Province'] == 'กระบี่')]
# Out:
#    Province total_OPD  Year
# 76   กระบี่    957304  2557

# %%
for i, province in enumerate(df_year_province['จังหวัด']):
    for j, temp_value in enumerate(new_df['Province']):
        # print(temp_value)
        if (temp_value == province) and (df_year_province['ปี'] == new_df['Year']):
        # if temp_value.loc[(temp_value['Province'] == province) & (temp_value['Year'] == i+2554)]:
            df_year_province[:, 'total_OPD'] = new_df.loc[new_df['Province']==temp_value, 'total_OPD'].values[0]
            # print(temp_value)

# %%
df_year_province['ปี']

# %%
new_df['Year']

# %%
new_df.loc[new_df['Province']=='กระบี่', 'total_OPD']

# %%
new_df.loc[new_df['Year'] == 2556]['Year'] == 2556

# %%
df_year_province

# %%
# for i, province in enumerate(df_year_province['จังหวัด']):
#     for j, temp_value in enumerate(new_df['Province']):

#         if (temp_value == province) and \
#            (df_year_province.loc[i, 'ปี'] == new_df.loc[j, 'Year']):

#             df_year_province.loc[i, 'total_OPD'] = new_df.loc[j, 'total_OPD']

# %%
new_df

# %%
df_year_province = df_year_province.merge(
    new_df[['Province', 'Year', 'total_OPD']],
    left_on=['จังหวัด', 'ปี'],
    right_on=['Province', 'Year'],
    how='left'
)
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm    Province  \
# 0     2554         กระบี่    647          krabi   5319.415247         NaN
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855         NaN
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979         NaN
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456         NaN
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768         NaN
# ...    ...            ...    ...            ...           ...         ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739    เพชรบุรี
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079   เพชรบูรณ์
# 1075  2567            เลย   1488           loei  10490.079232         เลย
# 1076  2567           แพร่   1185          phrae   6484.532497        แพร่
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567  แม่ฮ่องสอน
#
#         Year total_OPD
# 0        NaN       NaN
# 1        NaN       NaN
# ...

# %%
df_year_province.loc[df_year_province['จังหวัด'] == 'กระบี่']
# Out:
#         ปี จังหวัด  จำนวน province_en    area_sqkm Province    Year total_OPD
# 0     2554  กระบี่    647       krabi  5319.415247      NaN     NaN       NaN
# 77    2555  กระบี่    597       krabi  5319.415247      NaN     NaN       NaN
# 154   2556  กระบี่    584       krabi  5319.415247   กระบี่  2556.0   1110208
# 231   2557  กระบี่   1010       krabi  5319.415247   กระบี่  2557.0    957304
# 308   2558  กระบี่    790       krabi  5319.415247      NaN     NaN       NaN
# 385   2559  กระบี่    794       krabi  5319.415247   กระบี่  2559.0   1388593
# 462   2560  กระบี่    846       krabi  5319.415247   กระบี่  2560.0   1289648
# 539   2561  กระบี่    862       krabi  5319.415247   กระบี่  2561.0   1246366
# 616   2562  กระบี่    878       krabi  5319.415247   กระบี่  2562.0   1420358
# 693   2563  กระบี่    923       krabi  5319.415247   กระบี่  2563.0   1206856
# 770   2564  กระบี่   1044       krabi  5319.415247   กระบี่  2564.0    991758
# ...

# %%
df_year_province = df_year_province.drop(columns=['Province', 'Year'])
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm total_OPD
# 0     2554         กระบี่    647          krabi   5319.415247       NaN
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855       NaN
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979       NaN
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456       NaN
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768       NaN
# ...    ...            ...    ...            ...           ...       ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739   1745272
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079   3211189
# 1075  2567            เลย   1488           loei  10490.079232   2530043
# 1076  2567           แพร่   1185          phrae   6484.532497   1873193
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567    914187
#
# [1078 rows x 6 columns]

# %%
# df_year_province.to_csv('df_year_province_v2.csv')

# %%
# new_df.to_csv('all_OPD.csv')

# %%
new_df.loc[(new_df['Year'] == 2567) & (new_df['Province'] == 'อ่างทอง')]

# %% [markdown]
# ### Import Total Population
# - Get column named 'Total_population', then merge with df_year_province

# %%
df_total_pop = pd.read_excel('../add_data/01_nurse_midpop_area_province.xlsx')
df_total_pop
# Out:
#       year province_eng  province_code  region_6 health_reginal_13  \
# 0     2024      Bangkok              1   Central         Region 13
# 1     2024   Chiang Rai             34  Northern          Region 1
# 2     2024   Chiang Mai             27  Northern          Region 1
# 3     2024          Nan             32  Northern          Region 1
# 4     2024       Phayao             33  Northern          Region 1
# ...    ...          ...            ...       ...               ...
# 1073  2011   Narathiwat             77  Southern         Region 12
# 1074  2011      Pattani             75  Southern         Region 12
# 1075  2011         Yala             76  Southern         Region 12
# 1076  2011     Songkhla             71  Southern         Region 12
# 1077  2011        Satun             72  Southern         Region 12
#
#       number_of_nurses  Total_population   area  nurse_per_1000_population  \
# 0                41766           5362199   1564                       7.79
# ...

# %%
df_total_pop['province_eng'].unique()
# Out:
# array(['Bangkok', 'Chiang Rai', 'Chiang Mai', 'Nan', 'Phayao', 'Phrae',
#        'Mae Hong Son', 'Lampang', 'Lamphun', 'Tak', 'Phitsanulok',
#        'Phetchabun', 'Sukhothai', 'Uttaradit', 'Kamphaeng Phet',
#        'Chai Nat', 'Nakhon Sawan', 'Phichit', 'Uthai Thani',
#        'Nakhon Nayok', 'Nonthaburi', 'Pathum Thani',
#        'Phra Nakhon Si Ayutthaya', 'Lopburi', 'Saraburi', 'Sing Buri',
#        'Ang Thong', 'Kanchanaburi', 'Nakhon Pathom',
#        'Prachuap Khiri Khan', 'Phetchaburi', 'Ratchaburi',
#        'Samut Songkhram', 'Samut Sakhon', 'Suphan Buri', 'Chanthaburi',
#        'Chachoengsao', 'Chonburi', 'Trat', 'Prachinburi', 'Rayong',
#        'Samut Prakan', 'Sa Kaeo', 'Kalasin', 'Khon Kaen', 'Maha Sarakham',
#        'Roi Et', 'Nakhon Phanom', 'Bueng Kan', 'Loei', 'Sakon Nakhon',
#        'Nong Khai', 'Nong Bua Lamphu', 'Udon Thani', 'Chaiyaphum',
#        'Nakhon Ratchasima', 'Buriram', 'Surin', 'Mukdahan', 'Yasothon',
# ...

# %%
province_mapping2 = {'Bangkok':'กรุงเทพมหานคร', 'Chiang Rai':'เชียงราย', 'Chiang Mai':'เชียงใหม่', 'Nan':'น่าน', 'Phayao':'พะเยา', 'Phrae':'แพร่',
       'Mae Hong Son':'แม่ฮ่องสอน', 'Lampang':'ลำปาง', 'Lamphun':'ลำพูน', 'Tak':'ตาก', 'Phitsanulok':'พิษณุโลก',
       'Phetchabun':'เพชรบูรณ์', 'Sukhothai':'สุโขทัย', 'Uttaradit':'อุตรดิตถ์', 'Kamphaeng Phet':'กำแพงเพชร',
       'Chai Nat':'ชัยนาท', 'Nakhon Sawan':'นครสวรรค์', 'Phichit':'พิจิตร', 'Uthai Thani':'อุทัยธานี',
       'Nakhon Nayok':'นครนายก', 'Nonthaburi':'นนทบุรี', 'Pathum Thani':'ปทุมธานี',
       'Phra Nakhon Si Ayutthaya':'พระนครศรีอยุธยา', 'Lopburi':'ลพบุรี', 'Saraburi':'สระบุรี', 'Sing Buri':'สิงห์บุรี',
       'Ang Thong':'อ่างทอง', 'Kanchanaburi':'กาญจนบุรี', 'Nakhon Pathom':'นครปฐม',
       'Prachuap Khiri Khan':'ประจวบคีรีขันธ์', 'Phetchaburi':'เพชรบุรี', 'Ratchaburi':'ราชบุรี',
       'Samut Songkhram':'สมุทรสงคราม', 'Samut Sakhon':'สมุทรสาคร', 'Suphan Buri':'สุพรรณบุรี', 'Chanthaburi':'จันทบุรี',
       'Chachoengsao':'ฉะเชิงเทรา', 'Chonburi':'ชลบุรี', 'Trat':'ตราด', 'Prachinburi':'ปราจีนบุรี', 'Rayong':'ระยอง',
       'Samut Prakan':'สมุทรปราการ', 'Sa Kaeo':'สระแก้ว', 'Kalasin':'กาฬสินธุ์', 'Khon Kaen':'ขอนแก่น', 'Maha Sarakham':'มหาสารคาม',
       'Roi Et':'ร้อยเอ็ด', 'Nakhon Phanom':'นครพนม', 'Bueng Kan':'บึงกาฬ', 'Loei':'เลย', 'Sakon Nakhon':'สกลนคร',
       'Nong Khai':'หนองคาย', 'Nong Bua Lamphu':'หนองบัวลำภู', 'Udon Thani':'อุดรธานี', 'Chaiyaphum':'ชัยภูมิ',
       'Nakhon Ratchasima':'นครราชสีมา', 'Buriram':'บุรีรัมย์', 'Surin':'สุรินทร์', 'Mukdahan':'มุกดาหาร', 'Yasothon':'ยโสธร',
       'Sisaket':'ศรีสะเกษ', 'Amnat Charoen':'อำนาจเจริญ', 'Ubon Ratchathani':'อุบลราชธานี', 'Krabi':'กระบี่',
       'Chumphon':'ชุมพร', 'Nakhon Si Thammarat':'นครศรีธรรมราช', 'Phang Nga':'พังงา', 'Phuket':'ภูเก็ต', 'Ranong':'ระนอง',
       'Surat Thani':'สุราษฎร์ธานี', 'Trang':'ตรัง', 'Narathiwat':'นราธิวาส', 'Pattani':'ปัตตานี', 'Phatthalung':'พัทลุง',
       'Yala':'ยะลา', 'Songkhla':'สงขลา', 'Satun':'สตูล'}

df_total_pop['province_eng'] = df_total_pop['province_eng'].replace(province_mapping2)
df_total_pop
# Out:
#       year   province_eng  province_code  region_6 health_reginal_13  \
# 0     2024  กรุงเทพมหานคร              1   Central         Region 13
# 1     2024       เชียงราย             34  Northern          Region 1
# 2     2024      เชียงใหม่             27  Northern          Region 1
# 3     2024           น่าน             32  Northern          Region 1
# 4     2024          พะเยา             33  Northern          Region 1
# ...    ...            ...            ...       ...               ...
# 1073  2011       นราธิวาส             77  Southern         Region 12
# 1074  2011        ปัตตานี             75  Southern         Region 12
# 1075  2011           ยะลา             76  Southern         Region 12
# 1076  2011          สงขลา             71  Southern         Region 12
# 1077  2011           สตูล             72  Southern         Region 12
#
#       number_of_nurses  Total_population   area  nurse_per_1000_population  \
# ...

# %%
df_total_pop['province_eng'].unique()
# Out:
# array(['กรุงเทพมหานคร', 'เชียงราย', 'เชียงใหม่', 'น่าน', 'พะเยา', 'แพร่',
#        'แม่ฮ่องสอน', 'ลำปาง', 'ลำพูน', 'ตาก', 'พิษณุโลก', 'เพชรบูรณ์',
#        'สุโขทัย', 'อุตรดิตถ์', 'กำแพงเพชร', 'ชัยนาท', 'นครสวรรค์',
#        'พิจิตร', 'อุทัยธานี', 'นครนายก', 'นนทบุรี', 'ปทุมธานี',
#        'พระนครศรีอยุธยา', 'ลพบุรี', 'สระบุรี', 'สิงห์บุรี', 'อ่างทอง',
#        'กาญจนบุรี', 'นครปฐม', 'ประจวบคีรีขันธ์', 'เพชรบุรี', 'ราชบุรี',
#        'สมุทรสงคราม', 'สมุทรสาคร', 'สุพรรณบุรี', 'จันทบุรี', 'ฉะเชิงเทรา',
#        'ชลบุรี', 'ตราด', 'ปราจีนบุรี', 'ระยอง', 'สมุทรปราการ', 'สระแก้ว',
#        'กาฬสินธุ์', 'ขอนแก่น', 'มหาสารคาม', 'ร้อยเอ็ด', 'นครพนม',
#        'บึงกาฬ', 'เลย', 'สกลนคร', 'หนองคาย', 'หนองบัวลำภู', 'อุดรธานี',
#        'ชัยภูมิ', 'นครราชสีมา', 'บุรีรัมย์', 'สุรินทร์', 'มุกดาหาร',
#        'ยโสธร', 'ศรีสะเกษ', 'อำนาจเจริญ', 'อุบลราชธานี', 'กระบี่',
#        'ชุมพร', 'นครศรีธรรมราช', 'พังงา', 'ภูเก็ต', 'ระนอง',
# ...

# %%
df_total_pop['year'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011], dtype=int64)

# %%
year_mapping = {2024:2567, 2023:2566, 2022:2565, 2021:2564, 2020:2563, 2019:2562, 2018:2561, 2017:2560, 2016:2559, 2015:2558, 2014:2557,
                2013:2556, 2012:2555, 2011:2554}

df_total_pop['year'] = df_total_pop['year'].replace(year_mapping)
df_total_pop
# Out:
#       year   province_eng  province_code  region_6 health_reginal_13  \
# 0     2567  กรุงเทพมหานคร              1   Central         Region 13
# 1     2567       เชียงราย             34  Northern          Region 1
# 2     2567      เชียงใหม่             27  Northern          Region 1
# 3     2567           น่าน             32  Northern          Region 1
# 4     2567          พะเยา             33  Northern          Region 1
# ...    ...            ...            ...       ...               ...
# 1073  2554       นราธิวาส             77  Southern         Region 12
# 1074  2554        ปัตตานี             75  Southern         Region 12
# 1075  2554           ยะลา             76  Southern         Region 12
# 1076  2554          สงขลา             71  Southern         Region 12
# 1077  2554           สตูล             72  Southern         Region 12
#
#       number_of_nurses  Total_population   area  nurse_per_1000_population  \
# ...

# %%
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm total_OPD
# 0     2554         กระบี่    647          krabi   5319.415247       NaN
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855       NaN
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979       NaN
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456       NaN
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768       NaN
# ...    ...            ...    ...            ...           ...       ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739   1745272
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079   3211189
# 1075  2567            เลย   1488           loei  10490.079232   2530043
# 1076  2567           แพร่   1185          phrae   6484.532497   1873193
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567    914187
#
# [1078 rows x 6 columns]

# %%
# df_year_province = df_year_province.merge(
#     new_df[['Province', 'Year', 'total_OPD']],
#     left_on=['จังหวัด', 'ปี'],
#     right_on=['Province', 'Year'],
#     how='left'
# )
# df_year_province

# %%
df_year_province = df_year_province.merge(
    df_total_pop[['year', 'province_eng', 'Total_population']],
    left_on=['ปี', 'จังหวัด'],
    right_on=['year', 'province_eng'],
    how='left'
)
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm total_OPD  year  \
# 0     2554         กระบี่    647          krabi   5319.415247       NaN  2554
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855       NaN  2554
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979       NaN  2554
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456       NaN  2554
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768       NaN  2554
# ...    ...            ...    ...            ...           ...       ...   ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739   1745272  2567
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079   3211189  2567
# 1075  2567            เลย   1488           loei  10490.079232   2530043  2567
# 1076  2567           แพร่   1185          phrae   6484.532497   1873193  2567
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567    914187  2567
#
# ...

# %%
df_year_province = df_year_province.drop(columns=['province_eng', 'year'])
df_year_province
# Out:
#         ปี        จังหวัด  จำนวน    province_en     area_sqkm total_OPD  \
# 0     2554         กระบี่    647          krabi   5319.415247       NaN
# 1     2554  กรุงเทพมหานคร  22133        bangkok   1566.577855       NaN
# 2     2554      กาญจนบุรี   1196   kanchanaburi  19405.042979       NaN
# 3     2554      กาฬสินธุ์   1216        kalasin   6898.983456       NaN
# 4     2554      กำแพงเพชร    825  kamphaengphet   8520.494768       NaN
# ...    ...            ...    ...            ...           ...       ...
# 1073  2567       เพชรบุรี   1155    phetchaburi   6173.001739   1745272
# 1074  2567      เพชรบูรณ์   1742     phetchabun  12333.156079   3211189
# 1075  2567            เลย   1488           loei  10490.079232   2530043
# 1076  2567           แพร่   1185          phrae   6484.532497   1873193
# 1077  2567     แม่ฮ่องสอน    573     maehongson  12784.280567    914187
#
#       Total_population
# 0               435372
# 1              5688119
# 2               839345
# ...

# %%
# df_year_province.loc[(df_year_province['ปี'] == 2560) & (df_year_province['จังหวัด'] == 'อ่างทอง')]

# %%
# df_year_province[df_year_province['ปี'] == 2556]

# %%
region = {'Region1':['เชียงราย', 'เชียงใหม่', 'น่าน', 'พะเยา', 'แพร่', 'แม่ฮ่องสอน', 'ลำปาง', 'ลำพูน'],
          'Region2':['ตาก', 'พิษณุโลก', 'เพชรบูรณ์', 'สุโขทัย', 'อุตรดิตถ์']}

# %%
list(region.values())[0]
# Out:
# ['เชียงราย',
#  'เชียงใหม่',
#  'น่าน',
#  'พะเยา',
#  'แพร่',
#  'แม่ฮ่องสอน',
#  'ลำปาง',
#  'ลำพูน']

# %%
region.items()
# Out:
# dict_items([('Region1', ['เชียงราย', 'เชียงใหม่', 'น่าน', 'พะเยา', 'แพร่', 'แม่ฮ่องสอน', 'ลำปาง', 'ลำพูน']), ('Region2', ['ตาก', 'พิษณุโลก', 'เพชรบูรณ์', 'สุโขทัย', 'อุตรดิตถ์'])])

# %%
df_year_province.describe()
# Out:
#              ปี         จำนวน     area_sqkm  Total_population
# count  1078.000   1078.000000   1078.000000      1.078000e+03
# mean   2560.500   2117.671614   6701.855367      8.442144e+05
# std       4.033   3715.941157   4702.430381      7.147977e+05
# min    2554.000    359.000000    412.486728      1.751210e+05
# 25%    2557.000    946.500000   3487.650451      4.703365e+05
# 50%    2560.500   1405.500000   5582.585681      6.389710e+05
# 75%    2564.000   2040.500000   9525.605469      1.065416e+06
# max    2567.000  41766.000000  22056.887318      5.688119e+06

# %%
df_year_province[df_year_province['จำนวน'] == 359]
# Out:
#        ปี จังหวัด  จำนวน province_en    area_sqkm total_OPD  Total_population
# 178  2556  บึงกาฬ    359    buengkan  3979.545293    929015            414425

# %% [markdown]
# ### IPD2556

# %%
df_ipd_2556 = pd.read_excel('../add_data/dataset/IPD/IPD2556.xls')
df_ipd_2556

# %%
df_ipd_2556 = df_ipd_2556.loc[2:4:2]
df_ipd_2556

# %%
df_ipd_2556.columns

# %%
df_ipd_2556 = df_ipd_2556.drop(columns=[df_ipd_2556.columns[0]])
df_ipd_2556

# %%
df_ipd_2556 = df_ipd_2556.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_ipd_2556.columns)+1,2)])
df_ipd_2556

# %%
df_ipd_2556 = df_ipd_2556.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_ipd_2556

# %%
prov_2556 = df_ipd_2556.loc[2].values
prov_2556

# %%
no_patient_2556 = df_ipd_2556.loc[4].values
no_patient_2556

# %%
new_df = pd.DataFrame(data={'Province':prov_2556,
                            'total_IPD': no_patient_2556})
new_df

# %%
new_df['Year'] = 2556
new_df

# %%
# df_year_province = df_year_province.merge(df_2556[['Province', 'Year', 'total_IPD']], left_on=['จังหวัด', 'ปี'], right_on=['Province', 'Year'], how='left')
# df_year_province

# %%
# df_year_province = df_year_province.drop(columns=['Province', 'Year'])
# df_year_province

# %%
df_year_province.loc[(df_year_province['ปี']==2556) & (df_year_province['จังหวัด']=='อ่างทอง')]

# %% [markdown]
# ### IPD2557

# %%
df_ipd_2557 = pd.read_excel('../add_data/dataset/IPD/IPD2557.xls')
df_ipd_2557

# %%
df_ipd_2557 = df_ipd_2557.loc[2:4:2]
df_ipd_2557

# %%
df_ipd_2557 = df_ipd_2557.drop(columns=[df_ipd_2557.columns[0]])
df_ipd_2557

# %%
df_ipd_2557 = df_ipd_2557.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_ipd_2557.columns)+1,2)])
df_ipd_2557

# %%
df_ipd_2557 = df_ipd_2557.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_ipd_2557

# %%
prov_2557 = df_ipd_2557.loc[2].values
prov_2557

# %%
no_patient_2557 = df_ipd_2557.loc[4].values
no_patient_2557

# %%
df_2557 = pd.DataFrame(data={'Province':prov_2557,
                            'total_IPD': no_patient_2557})
df_2557

# %%
df_2557['Year'] = 2557
df_2557

# %%
new_df = pd.concat([new_df, df_2557], ignore_index=True)
new_df

# %%
# df_year_province = df_year_province.merge(df_2557[['Province', 'Year', 'total_IPD']], left_on=['จังหวัด', 'ปี'], right_on=['Province', 'Year'], how='left')
# df_year_province

# %%
# df_year_province = df_year_province.drop(columns=['Province', 'Year'])
# df_year_province

# %%
new_df.loc[(new_df['Year']==2557) & (new_df['Province']=='กระบี่')]

# %% [markdown]
# ### IPD2558
# - Data is so wired.

# %%
df_ipd_2558 = pd.read_excel('../add_data/dataset/IPD/IPD2558.xls')
df_ipd_2558.head(10)

# %%
df_ipd_2558 = df_ipd_2558.loc[2:4:2]
df_ipd_2558

# %%
df_ipd_2558.columns

# %%
df_ipd_2558 = df_ipd_2558.drop(columns=[df_ipd_2558.columns[0]])
df_ipd_2558

# %%
df_ipd_2558 = df_ipd_2558.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_ipd_2558.columns)+1,2)])
df_ipd_2558

# %%
df_ipd_2558 = df_ipd_2558.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_ipd_2558

# %%
prov_2558 = df_ipd_2558.loc[2].values
prov_2558

# %%
no_patient_2558 = df_ipd_2558.loc[4].values
no_patient_2558

# %%
df_2558 = pd.DataFrame(data={'Province':prov_2558,
                            'total_IPD': no_patient_2558})
df_2558

# %%
df_2558['Year'] = 2558
df_2558

# %%
df_year_province = df_year_province.merge(df_2558[['Province', 'Year', 'total_IPD']], left_on=['จังหวัด', 'ปี'], right_on=['Province', 'Year'], how='left')
df_year_province

# %%
df_year_province = df_year_province.drop(columns=['Province', 'Year'])
df_year_province

# %%
df_year_province = df_year_province.drop(columns=['total_IPD_x', 'total_IPD_y'])
df_year_province

# %%
df_year_province.loc[(df_year_province['ปี']==2558) & (df_year_province['จังหวัด']=='ภูเก็ต')]

# %% [markdown]
# ### IPD2559

# %%
df_ipd_2559 = pd.read_excel('../add_data/dataset/IPD/IPD2559.xls')
df_ipd_2559

# %%
df_ipd_2559 = df_ipd_2559.loc[2:4:2]
df_ipd_2559

# %%
df_ipd_2559 = df_ipd_2559.drop(columns=[df_ipd_2559.columns[0]])
df_ipd_2559

# %%
df_ipd_2559 = df_ipd_2559.drop(columns=[f'Unnamed: {i}' for i in range(4,len(df_ipd_2559.columns)+1,2)])
df_ipd_2559

# %%
df_ipd_2559 = df_ipd_2559.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'])
df_ipd_2559

# %%
prov_2559 = df_ipd_2559.loc[2].values
prov_2559

# %%
no_patient_2559 = df_ipd_2559.loc[4].values
no_patient_2559

# %%
df_2559 = pd.DataFrame(data={'Province':prov_2559,
                            'total_IPD': no_patient_2559})
df_2559

# %%
df_2559['Year'] = 2559
df_2559

# %%
new_df = pd.concat([new_df, df_2559], ignore_index=True)
new_df

# %%
new_df.loc[(new_df['Year']==2559) & (new_df['Province']=='อ่างทอง')]

# %% [markdown]
# ### IPD2560
# - Data is missing.

# %% [markdown]
# ### IPD2561

# %%
df_ipd_2560 = pd.read_excel('../add_data/dataset/IPD/IPD2561.xlsx')
df_ipd_2560
